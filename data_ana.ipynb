# %%
import pandas as pd
data = pd.read_csv(r"F:\python_prac\research-and-development-survey-2019-csv.csv",encoding= 'unicode_escape')

# %%
data.head(2)
# Out:
#                       Table           Breakdown Secondary_Breakdown  Year  \
# 0  01 Total R&D Expenditure  01_R&D Expenditure         1) Business  2012
# 1  01 Total R&D Expenditure  01_R&D Expenditure         1) Business  2014
#
#   Value        Unit
# 0  1193  $(million)
# 1  1246  $(million)

# %%
data.shape -- shows the data structure columns and rows
# Out:
# (900, 6)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=900, step=1)

# %%
data.columns
# Out:
# Index(['Table', 'Breakdown', 'Secondary_Breakdown', 'Year', 'Value', 'Unit'], dtype='object')

# %%
data.dtypes
# Out:
# Table                  object
# Breakdown              object
# Secondary_Breakdown    object
# Year                    int64
# Value                  object
# Unit                   object
# dtype: object

# %%
data['Table'].unique() --unique values of any column
# Out:
# array(['01 Total R&D Expenditure',
#        '02 Total R&D Expenditure by published industry',
#        '03 Businesses performing R&D by published industry',
#        '04 Total R&D Expenditure by ANZSIC industry',
#        '05 Purpose of Research', '06 Source of funds',
#        '07 Type of Research', '08 Type of expenditure',
#        '09 Expectation of future levels of R&D by sub-sect',
#        '10 Reason for carrying out or funding R&D by sub-s',
#        '11 Full-Time equivalent personnel by occupation',
#        '11 Headcount of personnel by occupation',
#        '12 Total R&D Expenditure by size',
#        '13 Businesses performing R&D by size',
#        '15 Broad purpose of research by sub-sector'], dtype=object)

# %%
data.nunique() --unique values of any column but count only, here based on all columns as its not defined
# Out:
# Table                   15
# Breakdown               86
# Secondary_Breakdown      9
# Year                     5
# Value                  354
# Unit                     3
# dtype: int64

# %%
data.count() -- count of rows in each column
# Out:
# Table                  900
# Breakdown              900
# Secondary_Breakdown    900
# Year                   900
# Value                  900
# Unit                   900
# dtype: int64

# %%
data["Table"].value_counts() --value count of each column, how many times each value occured
# Out:
# 15 Broad purpose of research by sub-sector            100
# 10 Reason for carrying out or funding R&D by sub-s    100
# 09 Expectation of future levels of R&D by sub-sect    100
# 08 Type of expenditure                                 80
# 02 Total R&D Expenditure by published industry         80
# 03 Businesses performing R&D by published industry     80
# 04 Total R&D Expenditure by ANZSIC industry            80
# 05 Purpose of Research                                 70
# 06 Source of funds                                     40
# 01 Total R&D Expenditure                               40
# 13 Businesses performing R&D by size                   35
# 12 Total R&D Expenditure by size                       35
# 07 Type of Research                                    20
# 11 Headcount of personnel by occupation                20
# 11 Full-Time equivalent personnel by occupation        20
# Name: Table, dtype: int64

# %%
data.info() -- gives info of the data set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Table                900 non-null    object
#  1   Breakdown            900 non-null    object
#  2   Secondary_Breakdown  900 non-null    object
#  3   Year                 900 non-null    int64
#  4   Value                900 non-null    object
#  5   Unit                 900 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 24.7+ KB

# %%
data.head(2)
# Out:
#                       Table           Breakdown Secondary_Breakdown  Year  \
# 0  01 Total R&D Expenditure  01_R&D Expenditure         1) Business  2012
# 1  01 Total R&D Expenditure  01_R&D Expenditure         1) Business  2014
#
#   Value        Unit
# 0  1193  $(million)
# 1  1246  $(million)

# %%
data['Year'].nunique()
# Out:
# 5

# %%
data[data['Year']==2012]
# Out:
#                                           Table  \
# 0                      01 Total R&D Expenditure
# 5                      01 Total R&D Expenditure
# 10                     01 Total R&D Expenditure
# 15                     01 Total R&D Expenditure
# 20                     01 Total R&D Expenditure
# ..                                          ...
# 875  15 Broad purpose of research by sub-sector
# 880  15 Broad purpose of research by sub-sector
# 885  15 Broad purpose of research by sub-sector
# 890  15 Broad purpose of research by sub-sector
# 895  15 Broad purpose of research by sub-sector
#
#                              Breakdown       Secondary_Breakdown  Year Value  \
# 0                   01_R&D Expenditure               1) Business  2012  1193
# 5                   01_R&D Expenditure             2) Government  2012   596
# 10                  01_R&D Expenditure       3) Higher Education  2012   836
# ...

# %%
# data.Year.count() --
# data.Year.value_counts()
# data[data.Year==2012]
data.groupby('Year').count()
data.groupby('Year').get_group(2012) --group by based on column alomg with its value
# Out:
#                                           Table  \
# 0                      01 Total R&D Expenditure
# 5                      01 Total R&D Expenditure
# 10                     01 Total R&D Expenditure
# 15                     01 Total R&D Expenditure
# 20                     01 Total R&D Expenditure
# ..                                          ...
# 875  15 Broad purpose of research by sub-sector
# 880  15 Broad purpose of research by sub-sector
# 885  15 Broad purpose of research by sub-sector
# 890  15 Broad purpose of research by sub-sector
# 895  15 Broad purpose of research by sub-sector
#
#                              Breakdown       Secondary_Breakdown  Year Value  \
# 0                   01_R&D Expenditure               1) Business  2012  1193
# 5                   01_R&D Expenditure             2) Government  2012   596
# 10                  01_R&D Expenditure       3) Higher Education  2012   836
# ...

# %%
# data.Value=300 -- we can assign the values as well in any column
# data.Value
# data.isnull().sum() --check if any value in the data set is null, notnull() will give not null count
# data.notnull().sum()
# Out:
# Table                  900
# Breakdown              900
# Secondary_Breakdown    900
# Year                   900
# Value                  900
# Unit                   900
# dtype: int64

# %%
data.head(2)
# data.rename(columns={'Value':'Value col'}) --changed only in the commnd, if want to chnge it parmanently use inplace=True
data.rename(columns={'Value':'Value col'},inplace=True)
data.head(2)
# Out:
#                       Table           Breakdown Secondary_Breakdown  Year  \
# 0  01 Total R&D Expenditure  01_R&D Expenditure         1) Business  2012
# 1  01 Total R&D Expenditure  01_R&D Expenditure         1) Business  2014
#
#    Value col        Unit
# 0        300  $(million)
# 1        300  $(million)

# %%
# data.head(2)
# data[data.Table.str.contains('Total')] --str.contains serch patterns in the data
# Out:
#                                 Table                Breakdown  \
# 0            01 Total R&D Expenditure       01_R&D Expenditure
# 1            01 Total R&D Expenditure       01_R&D Expenditure
# 2            01 Total R&D Expenditure       01_R&D Expenditure
# 3            01 Total R&D Expenditure       01_R&D Expenditure
# 4            01 Total R&D Expenditure       01_R&D Expenditure
# ..                                ...                      ...
# 760  12 Total R&D Expenditure by size  8)Total business sector
# 761  12 Total R&D Expenditure by size  8)Total business sector
# 762  12 Total R&D Expenditure by size  8)Total business sector
# 763  12 Total R&D Expenditure by size  8)Total business sector
# 764  12 Total R&D Expenditure by size  8)Total business sector
#
#     Secondary_Breakdown  Year  Value col        Unit
# 0           1) Business  2012        300  $(million)
# 1           1) Business  2014        300  $(million)
# ...

# %%
# data[(data['Value col']<=300) & (data.Year>2016)] --onditionl operations on data frame
# Out:
#                                           Table                 Breakdown  \
# 3                      01 Total R&D Expenditure        01_R&D Expenditure
# 4                      01 Total R&D Expenditure        01_R&D Expenditure
# 8                      01 Total R&D Expenditure        01_R&D Expenditure
# 9                      01 Total R&D Expenditure        01_R&D Expenditure
# 13                     01 Total R&D Expenditure        01_R&D Expenditure
# ..                                          ...                       ...
# 889  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 893  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 894  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 898  15 Broad purpose of research by sub-sector  16_Total Business Sector
# 899  15 Broad purpose of research by sub-sector  16_Total Business Sector
#
#           Secondary_Breakdown  Year  Value col        Unit
# ...

# %%
# data.Year.min()
# data.Year.max()
# data.groupby('Year').min() --calulating min,max direct on column values also after grouping all values
# Out:
#                          Table                             Breakdown  \
# Year
# 2012  01 Total R&D Expenditure  01_Agriculture, Forestry and Fishing
# 2014  01 Total R&D Expenditure  01_Agriculture, Forestry and Fishing
# 2016  01 Total R&D Expenditure  01_Agriculture, Forestry and Fishing
# 2018  01 Total R&D Expenditure  01_Agriculture, Forestry and Fishing
# 2019  01 Total R&D Expenditure  01_Agriculture, Forestry and Fishing
#
#      Secondary_Breakdown  Value col        Unit
# Year
# 2012          01_Primary      False  $(million)
# 2014          01_Primary      False  $(million)
# 2016          01_Primary      False  $(million)
# 2018          01_Primary      False  $(million)
# 2019          01_Primary      False  $(million)
